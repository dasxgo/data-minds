# %% [markdown]
# # **Premier League**

# %% [markdown]
# ### **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Load Datasets**

# %%
df_results = pd.read_csv('/home/dasxgo/dev/jupyter/data/results.csv')

# %%
df_stats = pd.read_csv('/home/dasxgo/dev/jupyter/data/stats.csv')
df_stats.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0              698.0                 256.0          21.0         12.0  ...
# 1              636.0                 216.0          14.0         16.0  ...
# 2              668.0                 214.0          15.0          8.0  ...
# 3              638.0                 226.0          19.0         10.0  ...
# 4              520.0                 184.0           6.0          5.0  ...
#
#    total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 0        918.0         258.0  25686.0                NaN                 1.0
# 1        897.0         231.0  24010.0                NaN                 2.0
# 2       1107.0         282.0  24150.0                NaN                 1.0
# 3        873.0         278.0  25592.0                NaN                 1.0
# 4        796.0         181.0  22200.0                NaN                 2.0
#
#    dispossessed  penalty_save  total_high_claim  punches     season
# 0           NaN           2.0              37.0     25.0  2006-2007
# 1           NaN           1.0              74.0     22.0  2006-2007
# 2           NaN           0.0              51.0     27.0  2006-2007
# 3           NaN           0.0              88.0     27.0  2006-2007
# 4           NaN           0.0              51.0     24.0  2006-2007
#
# [5 rows x 42 columns]

# %%
df_results.columns
# Out:
# Index(['home_team', 'away_team', 'home_goals', 'away_goals', 'result',
#        'season'],
#       dtype='object')

# %%
df_results.head()
# Out:
#           home_team         away_team  home_goals  away_goals result  \
# 0  Sheffield United         Liverpool         1.0         1.0      D
# 1           Arsenal       Aston Villa         1.0         1.0      D
# 2           Everton           Watford         2.0         1.0      H
# 3  Newcastle United    Wigan Athletic         2.0         1.0      H
# 4        Portsmouth  Blackburn Rovers         3.0         0.0      H
#
#       season
# 0  2006-2007
# 1  2006-2007
# 2  2006-2007
# 3  2006-2007
# 4  2006-2007

# %%
season_goals = df_results.groupby('season').sum(['home_goals'])
season_goals
# Out:
#            home_goals  away_goals
# season
# 2006-2007       552.0       379.0
# 2007-2008       581.0       421.0
# 2008-2009       532.0       410.0
# 2009-2010       645.0       408.0
# 2010-2011       617.0       446.0
# 2011-2012       604.0       462.0
# 2012-2013       592.0       471.0
# 2013-2014       598.0       454.0
# 2014-2015       560.0       415.0
# 2015-2016       567.0       459.0
# 2016-2017       607.0       457.0
# 2017-2018       582.0       436.0

# %%
plt.xticks(rotation=90);
sns.lineplot(x="season",y="home_goals",data=season_goals)
plt.show()

# %% [markdown]
# ### **Data Analysis**

# %%
df_results.shape
# Out:
# (4560, 6)

# %%
df_stats.shape
# Out:
# (240, 42)

# %%
df_results.describe()
# Out:
#         home_goals   away_goals
# count  4560.000000  4560.000000
# mean      1.543202     1.144298
# std       1.315163     1.139824
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     1.000000
# 75%       2.000000     2.000000
# max       9.000000     7.000000

# %% [markdown]
# ### **Data type**

# %%
df_results.dtypes
# Out:
# home_team      object
# away_team      object
# home_goals    float64
# away_goals    float64
# result         object
# season         object
# dtype: object

# %%
df_stats.dtypes
# Out:
# team                     object
# wins                    float64
# losses                  float64
# goals                   float64
# total_yel_card          float64
# total_red_card          float64
# total_scoring_att       float64
# ontarget_scoring_att    float64
# hit_woodwork            float64
# att_hd_goal             float64
# att_pen_goal            float64
# att_freekick_goal       float64
# att_ibox_goal           float64
# att_obox_goal           float64
# goal_fastbreak          float64
# total_offside           float64
# clean_sheet             float64
# goals_conceded          float64
# saves                   float64
# outfielder_block        float64
# interception            float64
# total_tackle            float64
# last_man_tackle         float64
# total_clearance         float64
# head_clearance          float64
# own_goals               float64
# penalty_conceded        float64
# pen_goals_conceded      float64
# total_pass              float64
# total_through_ball      float64
# total_long_balls        float64
# backward_pass           float64
# total_cross             float64
# corner_taken            float64
# touches                 float64
# big_chance_missed       float64
# clearance_off_line      float64
# dispossessed            float64
# penalty_save            float64
# total_high_claim        float64
# punches                 float64
# season                   object
# dtype: object

# %% [markdown]
# ### **Null values**

# %%
df_results.isnull().sum()
# Out:
# home_team     0
# away_team     0
# home_goals    0
# away_goals    0
# result        0
# season        0
# dtype: int64

# %%
df_stats.isnull().sum()
# Out:
# team                     0
# wins                     0
# losses                   0
# goals                    0
# total_yel_card           0
# total_red_card           0
# total_scoring_att        0
# ontarget_scoring_att     0
# hit_woodwork             0
# att_hd_goal              0
# att_pen_goal             0
# att_freekick_goal        0
# att_ibox_goal            0
# att_obox_goal            0
# goal_fastbreak           0
# total_offside            0
# clean_sheet              0
# goals_conceded           0
# saves                   20
# outfielder_block         0
# interception             0
# total_tackle             0
# last_man_tackle          0
# total_clearance          0
# head_clearance          20
# own_goals                0
# penalty_conceded         0
# pen_goals_conceded       0
# total_pass               0
# total_through_ball      20
# total_long_balls         0
# backward_pass           80
# total_cross              0
# corner_taken             0
# touches                  0
# big_chance_missed       80
# clearance_off_line       0
# dispossessed            20
# penalty_save             0
# total_high_claim         0
# punches                  0
# season                   0
# dtype: int64

# %%
away_minimum_goals = df_results['away_goals'].min()
away_minimum_goals
# Out:
# 0.0

# %%
local_maximo_goals = df_results['home_goals'].max()
local_maximo_goals
# Out:
# 9.0

# %% [markdown]
# ### **Manchester United**

# %%
mudf = df_stats['team'] == "Manchester United"
mudf = df_stats[mudf]

# %% [markdown]
# ### **Manchester United Goals**

# %%
plt.figure(figsize=(10, 6))
plt.style.use('seaborn-poster')
plt.xticks(rotation=90);
sns.barplot(x="season",y="goals",data=mudf)
plt.show()
# Out:
# /tmp/ipykernel_1593/3895395139.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# ### **Manchester United Wins - losses**

# %%
plt.xticks(rotation=90);
sns.lineplot(x="season",y="wins",data=mudf)
plt.show()
plt.xticks(rotation=90);
sns.lineplot(x="season",y="losses",data=mudf)
plt.show()

# %%
mudf
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 0    Manchester United  28.0     5.0   83.0            60.0             1.0
# 20   Manchester United  27.0     5.0   80.0            51.0             2.0
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 61   Manchester United  27.0     7.0   86.0            49.0             4.0
# 80   Manchester United  23.0     4.0   78.0            56.0             3.0
# 101  Manchester United  28.0     5.0   89.0            51.0             1.0
# 120  Manchester United  28.0     5.0   86.0            57.0             1.0
# 146  Manchester United  19.0    12.0   64.0            66.0             3.0
# 163  Manchester United  20.0     8.0   62.0            64.0             5.0
# 183  Manchester United  19.0    10.0   49.0            65.0             1.0
# 205  Manchester United  18.0     5.0   54.0            78.0             2.0
# 221  Manchester United  25.0     7.0   68.0            64.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0                698.0                 256.0          21.0         12.0  ...
# 20               696.0                 260.0          16.0         12.0  ...
# 40               715.0                 230.0           9.0          7.0  ...
# 61               695.0                 221.0          12.0         14.0  ...
# 80               618.0                 212.0          15.0         18.0  ...
# 101              646.0                 243.0          17.0         16.0  ...
# 120              561.0                 213.0          24.0         14.0  ...
# 146              526.0                 183.0          16.0         10.0  ...
# 163              512.0                 180.0          11.0         12.0  ...
# 183              430.0                 144.0           9.0          5.0  ...
# 205              591.0                 210.0          19.0          9.0  ...
# 221              512.0                 178.0          16.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 0          918.0         258.0  25686.0                NaN
# 20         936.0         261.0  26620.0                NaN
# 40        1039.0         257.0  30077.0                NaN
# 61        1156.0         297.0  28968.0                NaN
# 80        1005.0         243.0  26671.0               50.0
# 101       1018.0         279.0  28113.0               64.0
# 120        962.0         218.0  27264.0               65.0
# 146       1000.0         216.0  27367.0               38.0
# 163        908.0         214.0  29044.0               43.0
# 183        786.0         228.0  27542.0               28.0
# 205        848.0         217.0  28119.0               50.0
# 221        753.0         220.0  27525.0               42.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 0                   1.0           NaN           2.0              37.0
# 20                 10.0         627.0           0.0              47.0
# 40                  3.0         579.0           0.0              56.0
# 61                  2.0         622.0           0.0              65.0
# 80                  2.0         471.0           0.0              45.0
# 101                 3.0         521.0           1.0              37.0
# 120                 5.0         506.0           0.0              38.0
# 146                 1.0         491.0           0.0              32.0
# 163                 5.0         393.0           1.0              33.0
# 183                 4.0         522.0           0.0              29.0
# 205                 1.0         389.0           1.0              32.0
# 221                 4.0         399.0           0.0              20.0
#
#      punches     season
# 0       25.0  2006-2007
# 20      23.0  2007-2008
# 40      22.0  2008-2009
# 61      18.0  2009-2010
# 80      16.0  2010-2011
# 101     26.0  2011-2012
# 120     28.0  2012-2013
# 146     14.0  2013-2014
# 163      7.0  2014-2015
# 183     13.0  2015-2016
# 205      4.0  2016-2017
# 221      6.0  2017-2018
#
# [12 rows x 42 columns]

# %% [markdown]
# ### **Season**

# %%
season = mudf.groupby('season').sum()
season
# Out:
#                         team  wins  losses  goals  total_yel_card  \
# season
# 2006-2007  Manchester United  28.0     5.0   83.0            60.0
# 2007-2008  Manchester United  27.0     5.0   80.0            51.0
# 2008-2009  Manchester United  28.0     4.0   68.0            61.0
# 2009-2010  Manchester United  27.0     7.0   86.0            49.0
# 2010-2011  Manchester United  23.0     4.0   78.0            56.0
# 2011-2012  Manchester United  28.0     5.0   89.0            51.0
# 2012-2013  Manchester United  28.0     5.0   86.0            57.0
# 2013-2014  Manchester United  19.0    12.0   64.0            66.0
# 2014-2015  Manchester United  20.0     8.0   62.0            64.0
# 2015-2016  Manchester United  19.0    10.0   49.0            65.0
# 2016-2017  Manchester United  18.0     5.0   54.0            78.0
# 2017-2018  Manchester United  25.0     7.0   68.0            64.0
#
#            total_red_card  total_scoring_att  ontarget_scoring_att  \
# season
# 2006-2007             1.0              698.0                 256.0
# 2007-2008             2.0              696.0                 260.0
# 2008-2009             5.0              715.0                 230.0
# 2009-2010             4.0              695.0                 221.0
# 2010-2011             3.0              618.0                 212.0
# 2011-2012             1.0              646.0                 243.0
# 2012-2013             1.0              561.0                 213.0
# 2013-2014             3.0              526.0                 183.0
# 2014-2015             5.0              512.0                 180.0
# 2015-2016             1.0              430.0                 144.0
# 2016-2017             2.0              591.0                 210.0
# 2017-2018             1.0              512.0                 178.0
#
#            hit_woodwork  att_hd_goal  ...  backward_pass  total_cross  \
# season                                ...
# 2006-2007          21.0         12.0  ...            0.0        918.0
# 2007-2008          16.0         12.0  ...            0.0        936.0
# 2008-2009           9.0          7.0  ...            0.0       1039.0
# 2009-2010          12.0         14.0  ...            0.0       1156.0
# 2010-2011          15.0         18.0  ...         2411.0       1005.0
# 2011-2012          17.0         16.0  ...         2765.0       1018.0
# 2012-2013          24.0         14.0  ...         2727.0        962.0
# 2013-2014          16.0         10.0  ...         2898.0       1000.0
# 2014-2015          11.0         12.0  ...         3457.0        908.0
# 2015-2016           9.0          5.0  ...         3221.0        786.0
# 2016-2017          19.0          9.0  ...         3177.0        848.0
# 2017-2018          16.0         12.0  ...         2878.0        753.0
#
#            corner_taken  touches  big_chance_missed  clearance_off_line  \
# season
# 2006-2007         258.0  25686.0                0.0                 1.0
# 2007-2008         261.0  26620.0                0.0                10.0
# 2008-2009         257.0  30077.0                0.0                 3.0
# 2009-2010         297.0  28968.0                0.0                 2.0
# 2010-2011         243.0  26671.0               50.0                 2.0
# 2011-2012         279.0  28113.0               64.0                 3.0
# 2012-2013         218.0  27264.0               65.0                 5.0
# 2013-2014         216.0  27367.0               38.0                 1.0
# 2014-2015         214.0  29044.0               43.0                 5.0
# 2015-2016         228.0  27542.0               28.0                 4.0
# 2016-2017         217.0  28119.0               50.0                 1.0
# 2017-2018         220.0  27525.0               42.0                 4.0
#
#            dispossessed  penalty_save  total_high_claim  punches
# season
# 2006-2007           0.0           2.0              37.0     25.0
# 2007-2008         627.0           0.0              47.0     23.0
# 2008-2009         579.0           0.0              56.0     22.0
# 2009-2010         622.0           0.0              65.0     18.0
# 2010-2011         471.0           0.0              45.0     16.0
# 2011-2012         521.0           1.0              37.0     26.0
# 2012-2013         506.0           0.0              38.0     28.0
# 2013-2014         491.0           0.0              32.0     14.0
# 2014-2015         393.0           1.0              33.0      7.0
# 2015-2016         522.0           0.0              29.0     13.0
# 2016-2017         389.0           1.0              32.0      4.0
# 2017-2018         399.0           0.0              20.0      6.0
#
# [12 rows x 41 columns]

# %%
season['goals'].min()
# Out:
# 49.0

# %%
season_2017_2018 = season.loc['2017-2018']
season_2017_2018
# Out:
# wins                       25.0
# losses                      7.0
# goals                      68.0
# total_yel_card             64.0
# total_red_card              1.0
# total_scoring_att         512.0
# ontarget_scoring_att      178.0
# hit_woodwork               16.0
# att_hd_goal                12.0
# att_pen_goal                1.0
# att_freekick_goal           2.0
# att_ibox_goal              56.0
# att_obox_goal              13.0
# goal_fastbreak              4.0
# total_offside              88.0
# clean_sheet                19.0
# goals_conceded             28.0
# saves                     118.0
# outfielder_block          112.0
# interception              481.0
# total_tackle              564.0
# last_man_tackle             0.0
# total_clearance           853.0
# head_clearance            436.0
# own_goals                   2.0
# penalty_conceded            1.0
# pen_goals_conceded          1.0
# total_pass              20064.0
# total_through_ball         85.0
# total_long_balls         2308.0
# backward_pass            2878.0
# total_cross               753.0
# corner_taken              220.0
# touches                 27525.0
# big_chance_missed          42.0
# clearance_off_line          4.0
# dispossessed              399.0
# penalty_save                0.0
# total_high_claim           20.0
# punches                     6.0
# Name: 2017-2018, dtype: float64

# %%
season_2017_2018['goals']
# Out:
# 68.0

# %% [markdown]
# ### **Goals**

# %%
plt.figure(figsize=(10, 6))
plt.style.use('seaborn-poster')
plt.xticks(rotation=90);
sns.barplot(x="season",y="goals",data=df_stats)
plt.show()

plt.figure(figsize=(15, 12))
plt.style.use('seaborn-poster')
plt.xticks(rotation=90);
sns.barplot(x="goals",y="team",data=df_stats)
plt.show()
# Out:
# /tmp/ipykernel_1593/2814491669.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
# /tmp/ipykernel_1593/2814491669.py:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# ### **Penalty Save**

# %%
tm=df_stats.groupby(['team'])
tm=tm['penalty_save'].agg('max')
tm=pd.DataFrame(tm)
tm.reset_index(drop=False,inplace=True)
tm.set_index('penalty_save',inplace=True)
tm.sort_index(ascending=False)
tm.reset_index(drop=False,inplace=True)
tm=tm.nlargest(15,"penalty_save")

# %%
plt.xticks(rotation=90);
sns.scatterplot(x="team",y="penalty_save",data=tm)
plt.show()

# %% [markdown]
# ### **Touches for Team**

# %%
tm=df_stats.groupby(['team'])
tm=tm['touches'].agg('max')
tm=pd.DataFrame(tm)
tm.reset_index(drop=False,inplace=True)
tm.set_index('touches',inplace=True)
tm.sort_index(ascending=False)
tm.reset_index(drop=False,inplace=True)
tm=tm.nlargest(15,"touches")

# %%
plt.xticks(rotation=90);
sns.scatterplot(x="team",y="touches",data=tm)
plt.show()

# %% [markdown]
# ### **Yellow Card**

# %%
yel=df_stats.groupby('team').total_yel_card.mean()
yel=pd.DataFrame(yel)
yel.sort_values('total_yel_card',ascending=False,inplace=True)

# %%
sns.heatmap(yel,cmap="Wistia_r")
plt.show()

# %% [markdown]
# ## **Red Card**

# %%
red=df_stats.groupby('team').total_red_card.mean()
red=pd.DataFrame(red)
red.sort_values('total_red_card',inplace=True)

# %%
sns.heatmap(red,cmap="Reds")
plt.show()

# %% [markdown]
# ### **Finding the teams with total wins, losses and draws per total matches**

# %%
# Creating a new column draws
df_stats['draws'] = 38 - df_stats['wins'] - df_stats['losses']
# Changing the column location
pop_column = df_stats.pop('draws')
df_stats.insert(3, 'draws', pop_column)
# Creating a new column total_matches
df_stats['total_matches'] = df_stats['wins'] + df_stats['losses'] + df_stats['draws']
# Changing the column location
pop_column2 = df_stats.pop('total_matches')
df_stats.insert(4, 'total_matches', pop_column2)
df_stats.head()
# Out:
#                 team  wins  losses  draws  total_matches  goals  \
# 0  Manchester United  28.0     5.0    5.0           38.0   83.0
# 1            Chelsea  24.0     3.0   11.0           38.0   64.0
# 2          Liverpool  20.0    10.0    8.0           38.0   57.0
# 3            Arsenal  19.0     8.0   11.0           38.0   63.0
# 4  Tottenham Hotspur  17.0    12.0    9.0           38.0   57.0
#
#    total_yel_card  total_red_card  total_scoring_att  ontarget_scoring_att  \
# 0            60.0             1.0              698.0                 256.0
# 1            62.0             4.0              636.0                 216.0
# 2            44.0             0.0              668.0                 214.0
# 3            59.0             3.0              638.0                 226.0
# 4            48.0             3.0              520.0                 184.0
#
#    ...  total_cross  corner_taken  touches  big_chance_missed  \
# 0  ...        918.0         258.0  25686.0                NaN
# 1  ...        897.0         231.0  24010.0                NaN
# 2  ...       1107.0         282.0  24150.0                NaN
# 3  ...        873.0         278.0  25592.0                NaN
# 4  ...        796.0         181.0  22200.0                NaN
#
#    clearance_off_line  dispossessed  penalty_save  total_high_claim  punches  \
# 0                 1.0           NaN           2.0              37.0     25.0
# 1                 2.0           NaN           1.0              74.0     22.0
# 2                 1.0           NaN           0.0              51.0     27.0
# 3                 1.0           NaN           0.0              88.0     27.0
# 4                 2.0           NaN           0.0              51.0     24.0
#
#       season
# 0  2006-2007
# 1  2006-2007
# 2  2006-2007
# 3  2006-2007
# 4  2006-2007
#
# [5 rows x 44 columns]

# %%
# Creating a new dataframe to find the total wins, losses, draws, total_matches by grouping teams
df = df_stats.groupby('team').agg({'wins':'sum', 'losses':'sum', 'draws':'sum', 'total_matches':'sum'})
# Sorting the teams with most wins and getting the top 10 teams
df = df.sort_values(by = 'wins', ascending = False)
df.head(10)
# Out:
#                     wins  losses  draws  total_matches
# team
# Manchester United  290.0    77.0   89.0          456.0
# Chelsea            276.0    79.0  101.0          456.0
# Manchester City    256.0   107.0   93.0          456.0
# Arsenal            255.0    94.0  107.0          456.0
# Liverpool          234.0   103.0  119.0          456.0
# Tottenham Hotspur  228.0   116.0  112.0          456.0
# Everton            185.0   130.0  141.0          456.0
# West Ham United    127.0   181.0  110.0          418.0
# Newcastle United   116.0   171.0   93.0          380.0
# Stoke City         116.0   155.0  109.0          380.0

# %% [markdown]
# ### **Plotting the top 10 teams with most wins**

# %%
teams = df.index[:10]
wins = df.wins[:10]
matches = df.total_matches[:10]
plt.figure(figsize=(8, 4))
plt.style.use('ggplot')
# using x_index so that the bars can be placed side by side
x_index = np.arange(len(teams))
plt.bar(x_index - 0.25, wins, width = 0.5, label = 'Total Wins')
plt.bar(teams, matches, width = 0.35, label = 'Total Matches')
plt.ylabel('Total Wins per total matches', size = 10)
plt.xlabel('Teams', size = 10)
plt.xticks(rotation = 'vertical', size = 12)
plt.legend(loc = 4, prop = {'size': 10})
plt.show()

# %% [markdown]
# ### **Finding the teams with most losses**

# %%
# Creating a new dataframe 
df2 = df.sort_values(by = 'losses', ascending = False)
df2.head(10)
# Out:
#                        wins  losses  draws  total_matches
# team
# West Ham United       127.0   181.0  110.0          418.0
# Sunderland             95.0   181.0  104.0          380.0
# Newcastle United      116.0   171.0   93.0          380.0
# Stoke City            116.0   155.0  109.0          380.0
# West Bromwich Albion   93.0   154.0   95.0          342.0
# Aston Villa           113.0   150.0  117.0          380.0
# Everton               185.0   130.0  141.0          456.0
# Fulham                 87.0   128.0   89.0          304.0
# Wigan Athletic         70.0   126.0   70.0          266.0
# Swansea City           82.0   118.0   66.0          266.0

# %% [markdown]
# ### **Plotting the top 10 teams with most losses**

# %%
lost_teams = df2.index[:10]
losses = df.losses[:10]
total_matches = df.total_matches[:10]
plt.figure(figsize=(8, 4))
plt.style.use('ggplot')
x_index2 = np.arange(len(lost_teams))
plt.bar(x_index2 - 0.25, losses, width = 0.5, label = 'Total losses')
plt.bar(lost_teams, total_matches, width = 0.35, label = 'Total Matches')
plt.ylabel('Total losses per total matches', size = 14, color = 'black')
plt.xlabel('Teams', size = 15, color = 'black')
plt.xticks(rotation = 'vertical', size = 12, color = 'black')
plt.yticks(color = 'black')
plt.legend(loc = 4, prop = {'size': 10})
plt.show()
